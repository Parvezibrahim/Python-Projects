# %% [markdown]
# <a href="https://colab.research.google.com/github/Parvezibrahim/Python-Projects/blob/main/Stock_Price_Prediction_Using_MACD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Desciption : This Program uses the Moving Average Convergence/Divergence (MACD) crossover to determine when to buy and sell stock

# %%
#Import theb Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
#Load the Data :
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6bb1883a-1d87-4386-8ec2-f6972d4475ad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6bb1883a-1d87-4386-8ec2-f6972d4475ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AAPL.csv to AAPL.csv

# %%
#Store the data into a df
df = pd.read_csv('AAPL.csv')
#Set the date to be the index
df = df.set_index(pd.DatetimeIndex(df['Date'].values))
#Show the data
df
# Out:
#                   Date        Open        High         Low       Close  \
# 2014-09-29  2014-09-29  100.589996  100.690002   98.040001   99.620003
# 2014-10-06  2014-10-06   99.949997  102.379997   98.309998  100.730003
# 2014-10-13  2014-10-13  101.330002  101.779999   95.180000   97.669998
# 2014-10-20  2014-10-20   98.320000  105.489998   98.220001  105.220001
# 2014-10-27  2014-10-27  104.849998  108.040001  104.699997  108.000000
# ...                ...         ...         ...         ...         ...
# 2018-03-05  2018-03-05  175.210007  180.000000  174.270004  179.979996
# 2018-03-12  2018-03-12  180.289993  183.500000  177.619995  178.020004
# 2018-03-19  2018-03-19  177.320007  177.470001  164.940002  164.940002
# 2018-03-26  2018-03-26  168.070007  175.149994  165.190002  167.779999
# 2018-03-29  2018-03-29  167.804993  171.750000  166.899994  167.779999
#
#              Adj Close     Volume
# 2014-09-29   93.514290  142718700
# 2014-10-06   94.556244  280258200
# ...

# %%
#Visually show the stock Price
plt.figure(figsize=(18.2,6.5))
plt.plot(df['Close'],label='Close')
plt.xticks(rotation=45)

plt.title('Close Price History')
plt.xlabel('Date')
plt.ylabel('Price USD ($)')
plt.show()

# %%
#Calculate the MACF and signal line indiactors
#Calculate teh short term exponential moving average (EMA)
ShortEMA = df.Close.ewm(span=12,adjust=False).mean()
#Calculate the Long term Moving average (EMA)
LongEMA = df.Close.ewm(span=26 , adjust=False).mean()
#Calculaet the MACD line
MACD = ShortEMA-LongEMA
#Calculate teh Signal line
signal = MACD.ewm(span=9,adjust=False).mean()

# %%
#Plot the Chart
plt.figure(figsize=(18.2,6.5))
plt.plot(df.index,MACD,label  ='AAPL MACD',color='red')
plt.plot(df.index,signal,label= 'Signal Line',color ='blue')
plt.xticks(rotation= 45)
plt.legend(loc='upper left')
plt.show()

# %%
#Create new columns for the data
df['MACD'] = MACD
df['Signal Line'] = signal
#show the data
df
# Out:
#                   Date        Open        High         Low       Close  \
# 2014-09-29  2014-09-29  100.589996  100.690002   98.040001   99.620003
# 2014-10-06  2014-10-06   99.949997  102.379997   98.309998  100.730003
# 2014-10-13  2014-10-13  101.330002  101.779999   95.180000   97.669998
# 2014-10-20  2014-10-20   98.320000  105.489998   98.220001  105.220001
# 2014-10-27  2014-10-27  104.849998  108.040001  104.699997  108.000000
# ...                ...         ...         ...         ...         ...
# 2018-03-05  2018-03-05  175.210007  180.000000  174.270004  179.979996
# 2018-03-12  2018-03-12  180.289993  183.500000  177.619995  178.020004
# 2018-03-19  2018-03-19  177.320007  177.470001  164.940002  164.940002
# 2018-03-26  2018-03-26  168.070007  175.149994  165.190002  167.779999
# 2018-03-29  2018-03-29  167.804993  171.750000  166.899994  167.779999
#
#              Adj Close     Volume      MACD  Signal Line
# 2014-09-29   93.514290  142718700  0.000000     0.000000
# ...

# %%
#Create a function to signal when to buy and sell an asset
def buy_sell(signal):
  Buy = []
  Sell = []
  flag = -1


  for i in range(0,len(signal)):
    if signal['MACD'][i]> signal['Signal Line'][i]:
      Sell.append(np.nan)
      if flag !=1:
        Buy.append(signal['Close'][i])
        flag = 1
      else:
        Buy.append(np.nan)
    elif signal['MACD'][i]< signal['Signal Line'][i]:
      Buy.append(np.nan)
      if flag !=0:
        Sell.append(signal['Close'][i])
        flag = 0
      else:
        Sell.append(np.nan) 
    else:
      Buy.append(np.nan)
      Sell.append(np.nan) 


  return(Buy,Sell)

# %%
# Craete buy and selll column
a =buy_sell(df)
df["Buy_Signal_Price"]  = a[0]
df["Sell_Signal_Price"]  = a[1]

# %%
#Show the Data
df
# Out:
#                   Date        Open        High         Low       Close  \
# 2014-09-29  2014-09-29  100.589996  100.690002   98.040001   99.620003
# 2014-10-06  2014-10-06   99.949997  102.379997   98.309998  100.730003
# 2014-10-13  2014-10-13  101.330002  101.779999   95.180000   97.669998
# 2014-10-20  2014-10-20   98.320000  105.489998   98.220001  105.220001
# 2014-10-27  2014-10-27  104.849998  108.040001  104.699997  108.000000
# ...                ...         ...         ...         ...         ...
# 2018-03-05  2018-03-05  175.210007  180.000000  174.270004  179.979996
# 2018-03-12  2018-03-12  180.289993  183.500000  177.619995  178.020004
# 2018-03-19  2018-03-19  177.320007  177.470001  164.940002  164.940002
# 2018-03-26  2018-03-26  168.070007  175.149994  165.190002  167.779999
# 2018-03-29  2018-03-29  167.804993  171.750000  166.899994  167.779999
#
#              Adj Close     Volume      MACD  Signal Line  Buy_Signal_Price  \
# ...

# %%
#visualize show the stock buya nd sell signals
plt.figure(figsize=(18,6.5))
plt.scatter(df.index,df['Buy_Signal_Price'],color='green',label='Buy',marker='^',alpha=1)
plt.scatter(df.index,df['Sell_Signal_Price'],color='red',label='Sell',marker='v',alpha=1)
plt.plot(df['Close'],label='Close Price',alpha = 0.35)
plt.title('Close Price Buy and Sell Signals')
plt.xticks(rotation = 45)
plt.xlabel('Date')
plt.ylabel('Close Price USD($)')
plt.legend(loc = 'upper left')
plt.show()
